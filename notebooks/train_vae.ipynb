# %% [markdown]
# # VAE-FFN Controller Training
# This notebook trains the quantized Variational Autoencoder-Feed-Forward Network (VAE-FFN) on 10,000 simulated noisy stabilizer cycles matching the IBM Kingston backend calibration profile.

# %%
import numpy as np

# Configuration matching Section 3.1 hyperparameters
latent_dim = 8
epochs = 500
dataset_size = 10000

print(f'Initializing VAE-FFN training corpus with {dataset_size} simulated cycles...')
print(f'Latent dimension: {latent_dim}, Target Epochs: {epochs}')
